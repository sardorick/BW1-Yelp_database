# %%
import requests
from bs4  import BeautifulSoup
import pandas as pd
import numpy as np

from time import sleep
from random import randint
from warnings import warn
from time import time

# %% [markdown]
# # Data Needed
# name 1 webscraping
# Price range, reflected in € symbol ($= under $10. $$=11-30. $$$=31-60. $$$$= over $61) convert to euro.  1 webscraping
# Rating  1 webscraping
# Number of reviews  1 webscraping
# Category (List)  1 webscraping
# Neighborhood
#
# Location (any way to check proximity to popular places?)  2 webscraping
# Opening and closing time  2 webscraping
# Number of photos  2 webscraping
# Website 2 webscraping
# Features (List)  2 webscraping

# %% [markdown]
# ## Restaurants

# %%
url = f"https://www.yelp.com/search?find_desc=Restaurant&find_loc=Barcelona%2C+Spain&start=0"
response = requests.get(url)

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_r = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Restaurant&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_r[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))

# %%
# save to csv
pd.DataFrame([soup_r]).to_csv('restaurant_soup.csv')

# %%
price_range = [] 
ser = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()
class_container = 'border-color--default__09f24__NPAKY'
for row in ser:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.find_all(class_ = class_container)
    for tag in result:
        print(tag)
        # print(tag.text)
        # # print(   pd.Series(tag.text).str.extract(r'\d+.+(€+)').squeeze()  )
        # print('-'*100)

# %%
# Study case with first restaurant
# link to more information about each business


# accessing each business through its link in the name
first_page = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()[0]
first_page = BeautifulSoup(first_page, 'html.parser')
first_resto = first_page.select('.css-1egxyvc .css-1m051bw')[0]
link = first_resto['href']
url = f'https://wwww.yelp.com{link}'
response = requests.get(url)
details = BeautifulSoup(response.content, 'html.parser')

# %%
# example price range
# pages = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()

# for page in pages:
#     page = BeautifulSoup(page, 'html.parser')
#     page.select()

# %%
# details about each business
# request = 0
# start_time = time()

# soup_r2 = pd.DataFrame() 
# ser = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()
# for row in ser:
#     page = BeautifulSoup(row, 'html.parser')
#     a_tags = page.select('.css-1egxyvc .css-1m051bw')
#     for tag in a_tags:
#         # print(tag)
#         name = tag.text
#         link = tag['href']
#         url = f'https://wwww.yelp.com{link}'
#         response = requests.get(url)

#         # Pause the loop
#         sleep(randint(8,15))
#         print(response)
#         page = BeautifulSoup(response.content, 'html.parser')
#         soup_r2[name] = [page]

#         # Monitor the requests
#         request += 1
#         elapsed_time = time() - start_time
#         print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

#         # Throw a warning if request wasn't successful
#         if response.status_code != 200:
#             warn('Request: {}; Status code: {}'.format(request, response.status_code))

# %%
# Example, extracting location
location = ''
for adress in soup_r2['Cerveseria Catalana'][0].select('address .raw__09f24__T4Ezm'):
    location += adress.text + ';'


location
# Out:
# 'Carrer de Mallorca, 236 ;08008 Barcelona ;Spain ;'

# %%
# names = []
# ser = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()
# for row in ser:
#     soup = BeautifulSoup(row, 'html.parser')
#     result = soup.select('.css-1egxyvc .css-1m051bw')
#     for tag in result:
#         names.append(tag.text)

# pd.Series(names).value_counts()

# %% [markdown]
# ## Hotels

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_h = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Hotels&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_h[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))

# %%
# save soup_h
pd.DataFrame([soup_h]).to_csv('hotel_soup.csv')

# %%
# scraping from saved dataframe
names = []
ser = pd.read_csv('hotel_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('.css-1egxyvc .css-1m051bw')
    for tag in result:
        names.append(tag.text)

# names

# %%
# details about each business
# request = 0
# start_time = time()

# soup_h2 = pd.DataFrame() 
# ser = pd.read_csv('hotel_soup.csv').drop(columns='Unnamed: 0').squeeze()
# for row in ser [:13:-1]:
#     page = BeautifulSoup(row, 'html.parser')
#     a_tags = page.select('.css-1egxyvc .css-1m051bw')
#     for tag in a_tags:
#         # print(tag)
#         name = tag.text
#         link = tag['href']
#         url = f'https://wwww.yelp.com{link}'
#         response = requests.get(url)

#         # Pause the loop
#         sleep(randint(8,15))
#         print(response)
#         page = BeautifulSoup(response.content, 'html.parser')
#         soup_h2[name] = [page]

#         # Monitor the requests
#         request += 1
#         elapsed_time = time() - start_time
#         print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

#         # Throw a warning if request wasn't successful
#         if response.status_code != 200:
#             warn('Request: {}; Status code: {}'.format(request, response.status_code))

# %%
# due to yelp's blocking, data scraped in two parts. Made a mistake during 1 part and appended hotel data to soup_r2 (restaurant)
hotel_soup2 = pd.concat((soup_r2.iloc[:, 207:], soup_h2), axis=1)

# %%
# save file
hotel_soup2.to_csv('hotel_soup2.csv')

# %% [markdown]
# ## Pubs

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_p = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Pubs&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_p[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:24; Frequency: 0.07382303659802342 requests/s

# %%
# save soup_p
pd.DataFrame([soup_p]).to_csv('pub_soup.csv')

# %%
# scraping from saved dataframe
names = []
ser = pd.read_csv('pub_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('.css-1egxyvc .css-1m051bw')
    for tag in result:
        names.append(tag.text)
        # names.append(tag.text.split('.')[1].replace('\xa0', ''))

# names

# %%
# details about each business
request = 0
start_time = time()

soup_p2 = pd.DataFrame() 
ser = pd.read_csv('pub_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    page = BeautifulSoup(row, 'html.parser')
    a_tags = page.select('.css-1egxyvc .css-1m051bw')
    for tag in a_tags:
        # print(tag)
        name = tag.text
        link = tag['href']
        url = f'https://wwww.yelp.com{link}'
        response = requests.get(url)

        # Pause the loop
        sleep(randint(8,15))
        print(response)
        page = BeautifulSoup(response.content, 'html.parser')
        soup_p2[name] = [page]

        # Monitor the requests
        request += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

        # Throw a warning if request wasn't successful
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.0516109229935936 requests/s
# <Response [200]>
# Request:2; Frequency: 0.05060304528867494 requests/s
# <Response [200]>
# Request:3; Frequency: 0.058051047319173 requests/s
# <Response [200]>
# Request:4; Frequency: 0.06096284503237915 requests/s
# <Response [200]>
# Request:5; Frequency: 0.059917236266049854 requests/s
# <Response [200]>
# Request:6; Frequency: 0.05839132816956192 requests/s
# <Response [200]>
# Request:7; Frequency: 0.057956714995026144 requests/s
# <Response [200]>
# Request:8; Frequency: 0.058244291368306805 requests/s
# <Response [200]>
# Request:9; Frequency: 0.058636313270285026 requests/s
# <Response [200]>
# Request:10; Frequency: 0.059892521763434875 requests/s
# <Response [200]>
# Request:11; Frequency: 0.0608225552193219 requests/s
# <Response [200]>
# Request:12; Frequency: 0.060484615521334294 requests/s
# <Response [200]>
# Request:13; Frequency: 0.059688624818105857 requests/s
# <Response [200]>
# Request:14; Frequency: 0.06009625753272652 requests/s
# <Response [200]>
# Request:15; Frequency: 0.05999531704262353 requests/s
# <Response [200]>
# Request:16; Frequency: 0.059627564123842444 requests/s
# <Response [200]>
# Request:17; Frequency: 0.05929127126734443 requests/s
# <Response [200]>
# Request:18; Frequency: 0.058857248292324686 requests/s
# <Response [200]>
# Request:19; Frequency: 0.05965237588778258 requests/s
# <Response [200]>
# Request:20; Frequency: 0.06002780800617031 requests/s
# <Response [200]>
# Request:21; Frequency: 0.060588448501517074 requests/s
# <Response [200]>
# Request:22; Frequency: 0.06033860031426594 requests/s
# <Response [200]>
# Request:23; Frequency: 0.06008688809274435 requests/s
# <Response [200]>
# Request:24; Frequency: 0.06062237795195283 requests/s
# <Response [200]>
# Request:25; Frequency: 0.059920391908721664 requests/s
# <Response [200]>
# Request:26; Frequency: 0.06044847345735692 requests/s
# <Response [200]>
# Request:27; Frequency: 0.060219024548107916 requests/s
# <Response [200]>
# Request:28; Frequency: 0.060063203920937905 requests/s
# <Response [200]>
# Request:29; Frequency: 0.06038789744892131 requests/s
# <Response [200]>
# Request:30; Frequency: 0.0605188309069304 requests/s
# <Response [200]>
# Request:31; Frequency: 0.06016429625011092 requests/s
# <Response [200]>
# Request:32; Frequency: 0.059957299048582706 requests/s
# <Response [200]>
# Request:33; Frequency: 0.05986066989010467 requests/s
# <Response [200]>
# Request:34; Frequency: 0.060336187106351184 requests/s
# <Response [200]>
# Request:35; Frequency: 0.06009235018429108 requests/s
# <Response [200]>
# Request:36; Frequency: 0.059964103920124835 requests/s
# <Response [200]>
# Request:37; Frequency: 0.06033517537735369 requests/s
# <Response [200]>
# Request:38; Frequency: 0.06028197582381735 requests/s
# <Response [200]>
# Request:39; Frequency: 0.060724320749821176 requests/s
# <Response [200]>
# Request:40; Frequency: 0.060476562834216166 requests/s
# <Response [200]>
# Request:41; Frequency: 0.06033243632834761 requests/s
# <Response [200]>
# Request:42; Frequency: 0.060709037881417405 requests/s
# <Response [200]>
# Request:43; Frequency: 0.060871061816423065 requests/s
# <Response [200]>
# Request:44; Frequency: 0.06111245848357621 requests/s
# <Response [200]>
# Request:45; Frequency: 0.061083070462909256 requests/s
# <Response [200]>
# Request:46; Frequency: 0.06107331847457844 requests/s
# <Response [200]>
# Request:47; Frequency: 0.06100314051217118 requests/s
# <Response [200]>
# Request:48; Frequency: 0.060677523458915215 requests/s
# <Response [200]>
# Request:49; Frequency: 0.06064063290137831 requests/s
# <Response [200]>
# Request:50; Frequency: 0.06060069074827352 requests/s
# <Response [200]>
# Request:51; Frequency: 0.06087890832440946 requests/s
# <Response [200]>
# Request:52; Frequency: 0.060905082849104605 requests/s
# <Response [200]>
# Request:53; Frequency: 0.060911392090932555 requests/s
# <Response [200]>
# Request:54; Frequency: 0.060544876487505304 requests/s
# <Response [200]>
# Request:55; Frequency: 0.060392379178136286 requests/s
# <Response [200]>
# Request:56; Frequency: 0.06030039644210872 requests/s
# <Response [200]>
# Request:57; Frequency: 0.060573627756037376 requests/s
# <Response [200]>
# Request:58; Frequency: 0.06059021230531175 requests/s
# <Response [200]>
# Request:59; Frequency: 0.06038370270927682 requests/s
# <Response [200]>
# Request:60; Frequency: 0.06016742619352813 requests/s
# <Response [200]>
# Request:61; Frequency: 0.06001419067110265 requests/s
# <Response [200]>
# Request:62; Frequency: 0.06021201491605626 requests/s
# <Response [200]>
# Request:63; Frequency: 0.060177562484037994 requests/s
# <Response [200]>
# Request:64; Frequency: 0.06010933508399413 requests/s
# <Response [200]>
# Request:65; Frequency: 0.06024903004136408 requests/s
# <Response [200]>
# Request:66; Frequency: 0.06046385769133429 requests/s
# <Response [200]>
# Request:67; Frequency: 0.06066741684947382 requests/s
# <Response [200]>
# Request:68; Frequency: 0.06064506716473418 requests/s
# <Response [200]>
# Request:69; Frequency: 0.06088740207578311 requests/s
# <Response [200]>
# Request:70; Frequency: 0.06107124118721235 requests/s
# <Response [200]>
# Request:71; Frequency: 0.06128914834074611 requests/s
# <Response [200]>
# Request:72; Frequency: 0.0612134458511952 requests/s
# <Response [200]>
# Request:73; Frequency: 0.061197694420801314 requests/s
# <Response [200]>
# Request:74; Frequency: 0.061192754006955126 requests/s
# <Response [200]>
# Request:75; Frequency: 0.061166253752467266 requests/s
# <Response [200]>
# Request:76; Frequency: 0.0610487462189295 requests/s
# <Response [200]>
# Request:77; Frequency: 0.061152042671960796 requests/s
# <Response [200]>
# Request:78; Frequency: 0.060981238479615646 requests/s
# <Response [200]>
# Request:79; Frequency: 0.06082536314906153 requests/s
# <Response [200]>
# Request:80; Frequency: 0.0608892696488543 requests/s
# <Response [200]>
# Request:81; Frequency: 0.06098931479500448 requests/s
# <Response [200]>
# Request:82; Frequency: 0.061129578253259736 requests/s
# <Response [200]>
# Request:83; Frequency: 0.06126530206181268 requests/s
# <Response [200]>
# Request:84; Frequency: 0.06110558399534433 requests/s
# <Response [200]>
# Request:85; Frequency: 0.06111160628358835 requests/s
# <Response [200]>
# Request:86; Frequency: 0.06111878909485692 requests/s
# <Response [200]>
# Request:87; Frequency: 0.060985743491901896 requests/s
# <Response [200]>
# Request:88; Frequency: 0.06099788768641192 requests/s
# <Response [200]>
# Request:89; Frequency: 0.06111838687131148 requests/s
# <Response [200]>
# Request:90; Frequency: 0.061111999069859445 requests/s
# <Response [200]>
# Request:91; Frequency: 0.06106833664436844 requests/s
# <Response [200]>
# Request:92; Frequency: 0.061234423023226216 requests/s
# <Response [200]>
# Request:93; Frequency: 0.061127192568122525 requests/s
# <Response [200]>
# Request:94; Frequency: 0.06113218161607871 requests/s
# <Response [200]>
# Request:95; Frequency: 0.061074129706571306 requests/s
# <Response [200]>
# Request:96; Frequency: 0.06105040368532056 requests/s
# <Response [200]>
# Request:97; Frequency: 0.0609211589526082 requests/s
# <Response [200]>
# Request:98; Frequency: 0.060870765771008424 requests/s
# <Response [200]>
# Request:99; Frequency: 0.0608714410249791 requests/s
# <Response [200]>
# Request:100; Frequency: 0.06088327849145729 requests/s
# <Response [200]>
# Request:101; Frequency: 0.06098405045070486 requests/s
# <Response [200]>
# Request:102; Frequency: 0.061027466909206525 requests/s
# <Response [200]>
# Request:103; Frequency: 0.06105123269970088 requests/s
# <Response [200]>
# Request:104; Frequency: 0.061173737547725864 requests/s
# <Response [200]>
# Request:105; Frequency: 0.061320338142212154 requests/s
# <Response [200]>
# Request:106; Frequency: 0.061237740025083996 requests/s
# <Response [200]>
# Request:107; Frequency: 0.06137077440444375 requests/s
# <Response [200]>
# Request:108; Frequency: 0.06132009477915466 requests/s
# <Response [200]>
# Request:109; Frequency: 0.06127924219334304 requests/s
# <Response [200]>
# Request:110; Frequency: 0.06144440389563976 requests/s
# <Response [200]>
# Request:111; Frequency: 0.0615941458609057 requests/s
# <Response [200]>
# Request:112; Frequency: 0.06160334398341873 requests/s
# <Response [200]>
# Request:113; Frequency: 0.06147630631413509 requests/s
# <Response [200]>
# Request:114; Frequency: 0.061429349620205305 requests/s
# <Response [200]>
# Request:115; Frequency: 0.061434187353446634 requests/s
# <Response [200]>
# Request:116; Frequency: 0.06137680863972995 requests/s
# <Response [200]>
# Request:117; Frequency: 0.061506518932134706 requests/s
# <Response [200]>
# Request:118; Frequency: 0.061447867744669 requests/s
# <Response [200]>
# Request:119; Frequency: 0.06140106972843418 requests/s
# <Response [200]>
# Request:120; Frequency: 0.06130852820196259 requests/s
# <Response [200]>
# Request:121; Frequency: 0.06129415820243327 requests/s
# <Response [200]>
# Request:122; Frequency: 0.061282399402311956 requests/s
# <Response [200]>
# Request:123; Frequency: 0.06142544373970557 requests/s
# <Response [200]>
# Request:124; Frequency: 0.06140581763210354 requests/s
# <Response [200]>
# Request:125; Frequency: 0.061370482942642114 requests/s
# <Response [200]>
# Request:126; Frequency: 0.06148995662224652 requests/s
# <Response [200]>
# Request:127; Frequency: 0.06159654433886871 requests/s
# <Response [200]>
# Request:128; Frequency: 0.06156281003034281 requests/s
# <Response [200]>
# Request:129; Frequency: 0.06160706941213323 requests/s
# <Response [200]>
# Request:130; Frequency: 0.06154417791317227 requests/s
# <Response [200]>
# Request:131; Frequency: 0.06143823838867841 requests/s
# <Response [200]>
# Request:132; Frequency: 0.061474731483669075 requests/s
# <Response [200]>
# Request:133; Frequency: 0.061452111661536246 requests/s
# <Response [200]>
# Request:134; Frequency: 0.06138253677103673 requests/s
# <Response [200]>
# Request:135; Frequency: 0.061369046102414365 requests/s
# <Response [200]>
# Request:136; Frequency: 0.06133953170379994 requests/s
# <Response [200]>
# Request:137; Frequency: 0.061331422530713546 requests/s
# <Response [200]>
# Request:138; Frequency: 0.06141218280005064 requests/s
# <Response [200]>
# Request:139; Frequency: 0.06138743213339842 requests/s
# <Response [200]>
# Request:140; Frequency: 0.06143989610374712 requests/s
# <Response [200]>
# Request:141; Frequency: 0.06139464564313636 requests/s
# <Response [200]>
# Request:142; Frequency: 0.06152237280369916 requests/s
# <Response [200]>
# Request:143; Frequency: 0.0615906406199074 requests/s
# <Response [200]>
# Request:144; Frequency: 0.06160038765426554 requests/s
# <Response [200]>
# Request:145; Frequency: 0.06149791042808369 requests/s
# <Response [200]>
# Request:146; Frequency: 0.061393696236478126 requests/s
# <Response [200]>
# Request:147; Frequency: 0.0614852785232591 requests/s
# <Response [200]>
# Request:148; Frequency: 0.061566674364829314 requests/s
# <Response [200]>
# Request:149; Frequency: 0.061585754927800766 requests/s
# <Response [200]>
# Request:150; Frequency: 0.06160319696349894 requests/s
# <Response [200]>
# Request:151; Frequency: 0.06164824072333775 requests/s
# <Response [200]>
# Request:152; Frequency: 0.06160286209369931 requests/s
# <Response [200]>
# Request:153; Frequency: 0.061566598611344836 requests/s
# <Response [200]>
# Request:154; Frequency: 0.06150800283347447 requests/s
# <Response [200]>
# Request:155; Frequency: 0.061540777064546276 requests/s
# <Response [200]>
# Request:156; Frequency: 0.06156197474368236 requests/s
# <Response [200]>
# Request:157; Frequency: 0.06160999472258615 requests/s
# <Response [200]>
# Request:158; Frequency: 0.06172534996898826 requests/s
# <Response [200]>
# Request:159; Frequency: 0.06176088258469934 requests/s
# <Response [200]>
# Request:160; Frequency: 0.061827582580963346 requests/s
# <Response [200]>
# Request:161; Frequency: 0.06190546049771886 requests/s
# <Response [200]>
# Request:162; Frequency: 0.06187911643910696 requests/s
# <Response [200]>
# Request:163; Frequency: 0.061806083819769986 requests/s
# <Response [200]>
# Request:164; Frequency: 0.06188690055398889 requests/s
# <Response [200]>
# Request:165; Frequency: 0.06185568423972667 requests/s
# <Response [200]>
# Request:166; Frequency: 0.061840432983640475 requests/s
# <Response [200]>
# Request:167; Frequency: 0.06178744908189866 requests/s
# <Response [200]>
# Request:168; Frequency: 0.06177425814191651 requests/s
# <Response [200]>
# Request:169; Frequency: 0.061744937461581405 requests/s
# <Response [200]>
# Request:170; Frequency: 0.06177916040589085 requests/s
# <Response [200]>
# Request:171; Frequency: 0.06179775848165537 requests/s
# <Response [200]>
# Request:172; Frequency: 0.061830947538153304 requests/s
# <Response [200]>
# Request:173; Frequency: 0.06180493394178621 requests/s
# <Response [200]>
# Request:174; Frequency: 0.06182698766189066 requests/s
# <Response [200]>
# Request:175; Frequency: 0.06181582202224984 requests/s
# <Response [200]>
# Request:176; Frequency: 0.061871080005792146 requests/s
# <Response [200]>
# Request:177; Frequency: 0.061885016494439886 requests/s
# <Response [200]>
# Request:178; Frequency: 0.061887249126782416 requests/s
# <Response [200]>
# Request:179; Frequency: 0.06190223462165156 requests/s
# <Response [200]>
# Request:180; Frequency: 0.06191809231624544 requests/s
# <Response [200]>
# Request:181; Frequency: 0.061844374729892765 requests/s
# <Response [200]>
# Request:182; Frequency: 0.0618425078914193 requests/s
# <Response [200]>
# Request:183; Frequency: 0.06190856251856599 requests/s
# <Response [200]>
# Request:184; Frequency: 0.06198179391340733 requests/s
# <Response [200]>
# Request:185; Frequency: 0.061949725137681405 requests/s
# <Response [200]>
# Request:186; Frequency: 0.06193843130674679 requests/s
# <Response [200]>
# Request:187; Frequency: 0.06198073745098808 requests/s
# <Response [200]>
# Request:188; Frequency: 0.06198817605758299 requests/s
# <Response [200]>
# Request:189; Frequency: 0.0619641689835698 requests/s
# <Response [200]>
# Request:190; Frequency: 0.06192823912268828 requests/s
# <Response [200]>
# Request:191; Frequency: 0.061881038311680604 requests/s
# <Response [200]>
# Request:192; Frequency: 0.061899782419173564 requests/s
# <Response [200]>
# Request:193; Frequency: 0.06192191632486078 requests/s
# <Response [200]>
# Request:194; Frequency: 0.061885150332200003 requests/s
# <Response [200]>
# Request:195; Frequency: 0.06189543849290376 requests/s
# <Response [200]>
# Request:196; Frequency: 0.061881778758725484 requests/s
# <Response [200]>
# Request:197; Frequency: 0.06187937274415609 requests/s
# <Response [200]>
# Request:198; Frequency: 0.06186112469094755 requests/s
# <Response [200]>
# Request:199; Frequency: 0.061920682836491533 requests/s
# <Response [200]>
# Request:200; Frequency: 0.06187879412993858 requests/s
# <Response [200]>
# Request:201; Frequency: 0.061958862600312456 requests/s
# <Response [200]>
# Request:202; Frequency: 0.06202443161630782 requests/s
# <Response [200]>
# Request:203; Frequency: 0.0620410497394868 requests/s
# <Response [200]>
# Request:204; Frequency: 0.062027092069556866 requests/s
# <Response [200]>
# Request:205; Frequency: 0.06205323274692936 requests/s
# <Response [200]>
# Request:206; Frequency: 0.06203908594163474 requests/s
# <Response [200]>
# Request:207; Frequency: 0.062029272203972675 requests/s
# <Response [200]>
# Request:208; Frequency: 0.061995389946955845 requests/s
# <Response [200]>
# Request:209; Frequency: 0.061915466354792836 requests/s
# <Response [200]>
# Request:210; Frequency: 0.061831820600113205 requests/s
# <Response [200]>
# Request:211; Frequency: 0.061826144349261127 requests/s
# <Response [200]>
# Request:212; Frequency: 0.061806787955621535 requests/s
# <Response [200]>
# Request:213; Frequency: 0.061740425587128 requests/s
# <Response [200]>
# Request:214; Frequency: 0.061750386610932774 requests/s
# <Response [200]>
# Request:215; Frequency: 0.061771001044013035 requests/s
# <Response [200]>
# Request:216; Frequency: 0.06182111966037533 requests/s
# <Response [200]>
# Request:217; Frequency: 0.061904729816294114 requests/s
# <Response [200]>
# Request:218; Frequency: 0.06192780858174258 requests/s
# <Response [200]>
# Request:219; Frequency: 0.061966985838829716 requests/s
# <Response [200]>
# Request:220; Frequency: 0.062009845133889636 requests/s
# <Response [200]>
# Request:221; Frequency: 0.062040837473795844 requests/s
# <Response [200]>
# Request:222; Frequency: 0.062005726589089524 requests/s
# <Response [200]>
# Request:223; Frequency: 0.061983275680804785 requests/s
# <Response [200]>
# Request:224; Frequency: 0.06201358736395589 requests/s
# <Response [200]>
# Request:225; Frequency: 0.06201720988667182 requests/s
# <Response [200]>
# Request:226; Frequency: 0.061975559314371854 requests/s
# <Response [200]>
# Request:227; Frequency: 0.061940908276025844 requests/s
# <Response [200]>
# Request:228; Frequency: 0.06186645278694075 requests/s
# <Response [200]>
# Request:229; Frequency: 0.06186220827618164 requests/s
# <Response [200]>
# Request:230; Frequency: 0.06183639097598055 requests/s
# <Response [200]>
# Request:231; Frequency: 0.061774298513207565 requests/s
# <Response [200]>
# Request:232; Frequency: 0.06172250144534409 requests/s
# <Response [200]>
# Request:233; Frequency: 0.06172289418167704 requests/s
# <Response [200]>
# Request:234; Frequency: 0.06171094279754891 requests/s
# <Response [200]>
# Request:235; Frequency: 0.06168718669916219 requests/s
# <Response [200]>
# Request:236; Frequency: 0.06170007695860139 requests/s
# <Response [200]>
# Request:237; Frequency: 0.06163870179121194 requests/s
# <Response [200]>
# Request:238; Frequency: 0.061609330014839925 requests/s
# <Response [200]>
# Request:239; Frequency: 0.061629570866239075 requests/s
# <Response [200]>
# Request:240; Frequency: 0.06170200167646572 requests/s

# %%
soup_p2.to_csv('pub_soup2.csv')
