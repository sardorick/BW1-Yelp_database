# %%
import requests
from bs4  import BeautifulSoup
import pandas as pd

from time import sleep
from random import randint
from warnings import warn
from IPython.core.display import clear_output
from time import time

# %% [markdown]
# # Data Needed
# name 1 webscraping
# Price range, reflected in € symbol ($= under $10. $$=11-30. $$$=31-60. $$$$= over $61) convert to euro.  1 webscraping
# Rating  1 webscraping
# Number of reviews  1 webscraping
# Category (List)  1 webscraping
# Neighborhood
#
# Location (any way to check proximity to popular places?)  2 webscraping
# Opening and closing time  2 webscraping
# Number of photos  2 webscraping
# Website 2 webscraping
# Features (List)  2 webscraping

# %% [markdown]
# ## Restaurants

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_r = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Restaurant&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_r[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))

# %%
# save to csv
pd.DataFrame([soup_r]).to_csv('restaurant_soup.csv')

# %%
# Study case with first restaurant
# link to more information about each business


# accessing each business through its link in the name
first_page = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()[0]
first_page = BeautifulSoup(first_page, 'html.parser')
first_resto = first_page.select('.css-1egxyvc .css-1m051bw')[0]
link = first_resto['href']
url = f'https://wwww.yelp.com{link}'
response = requests.get(url)
details = BeautifulSoup(response.content, 'html.parser')

# %%
test = pd.DataFrame()
test['hey'] = 1
test['two'] = 2

test.shape
# Out:
# (0, 2)

# %%
# details about each business
request = 0
start_time = time()

soup_r2 = pd.DataFrame() 
ser = pd.read_csv('restaurant_soup').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    page = BeautifulSoup(row, 'html.parser')
    a_tags = page.select('.css-1egxyvc .css-1m051bw')
    for tag in a_tags:
        # print(tag)
        name = tag.text
        link = tag['href']
        url = f'https://wwww.yelp.com{link}'
        response = requests.get(url)

        # Pause the loop
        sleep(randint(8,15))
        print(response)
        page = BeautifulSoup(response.content, 'html.parser')
        soup_r2[name] = page

        # Monitor the requests
        request += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
        clear_output(wait = True)

        # Throw a warning if request wasn't successful
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:240; Frequency: 0.06457316273729564 requests/s

# %%
soup_r2'Cerveseria Catalana'
# soup_r2.keys()
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(no-j/,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async="" src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"/><style data-emotion-css="0 xl0fej swh6wo 12twv4h phmrhf 110vchp tza3mu 1enow5j gme0a6 1615add rv5oe7 1sie4w0 xlzvdl 2sacua qgunke 1sb02f4 11w66x2 15j7fnr war30n 79elbk 1t0p8qh 1suk6u5 1evauet 7cc6f4 ije6j5 ralh0w wonnhn 1fygppl 1udg11w ux5mu6 1m051bw rucvyo tnmzvl 1nrzw89 1fnccdf chan6m 6a0jil 1oibaro 1ozv8h4 1naudvp zgqpnl pkiipu gutk1c 1txq1ov inq9gi 1c2abjj 12i50in v9pqhn 70gpq2 14ji0ov 177wmrn 1lr1m88 s0rd9z khf3h6 13f7u47 15yaebe 5rlc86 p9tsht yemx9b 5xxkcx 143i5i0 1as1tch yo8rv5 1ozp3ve 1jse0gy 1afdtvl 1nx1n9o 3u4ty whee3x jy9enz 19u8808 o3ymor foyide 1lx34my 144i0wq 1kq79li 1rjq8gp 16agjqd 1uk2nuw 19cdu5a 1ajt4zc 1gquror 12anxc3 1kuwv4w 4zp531 jcl426 1h0y4i5 1i6fjil nyjpex 1hyrt2g na3oda 1katklm 65oj21 chpjjq 17zd32g 6iao2p ekqzi1 1vvgets 1ylbdp9 m37q3f 1op2dfh dh50jt yyr98k 4mfze4 1jac6c2 cv1jz2 fksa8h 147xtl9 19sk4h4 12dgwvn 1fdy0l5 q8l0re 1d6kqw4 1ir4e44 9u9gtr syqjjh t8izln 1um3nx r9996t 1p9ibgf cktstf 1t7f977 xxqqxs qyp8bo 106vfgv 1wayfxy 1p80smk xp8w2v 1vhakgw 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz ...
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.critical_css = window.yelp.critical_css || {};
#         window.yelp.critical_css.css_map = {};
#     </script>
# <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
# <meta name="critical_css_middleware"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-commons-pkg.yji-f3418387f78748de92d9.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-483556bfb011db885de1b785b53a88611d47139e-pkg.yji-32657c5404f9860b7073.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-8daad50f11ea24801306f19a9b13da6bf261d58d-pkg.yji-d43b2ad4d383c516f4a0.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-6d99a1f5833cab3bb3bc2e449a12e7eb20b0a491-pkg.yji-9b25bb2523454a7e429d.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-075b547d8068ffa7f3654f89300660a59b657565-pkg.yji-083cecb861277ebb1cd7.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-gondola-biz-details-pkg.yji-e23b1780d32fe0530f34.css" rel="stylesheet"/><link as="style" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-ad59b36f17920d25a77f.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-88ca5af3b99587234325.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-8343c8d822bd08587711.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-456daedc5567db2c2247.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css" rel="preload"/>
# <link as="style" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-dad5e49120422e2e9d29.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-775b6c3aa54c4e6f1583.chunk.css" rel="preload"/>
# <link as="style" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-82b846e7751e856d88c1.chunk.css" rel="preload"/>
# <link as="script" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-5d87a390c86fc7d0bdf9.chunk.js" rel="preload"/>
# <link as="script" data-chunk="ClaimReminderGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-5b5584a8c410c624ac3c.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-UnconfirmedReviewAlert" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-5f0659d2a4a4f5f55cf0.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-1be7ee6c6c127d99d93e.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-af0fc3a59b1fbdc8c4d1.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-f40cee3c2224261676eb4b46f723e0867d8329bc.yji-581b49d8005d868cf0c0.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-fbb2c05ce72727d2717b02d2c156fdd517bca70a.yji-3018a4f5fe4b3226407a.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8a92b8a262dbf9c3601880010c35a404c0e06edb.yji-ef884a6ded959e9afbc6.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-e55b41b68c176872ae025c8e120f2420c303617a.yji-7b1f1473bce5b8f97dc3.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-34b00f1306f8d2652eed.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ReviewHighlights" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewHighlights.yji-1389fc94b8fad2eac6e6.chunk.js" rel="preload"/>
# <link as="script" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-e8661b65e75188e5ee8c.chunk.js" rel="preload"/>
# <link as="script" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-b5b1a5fa1229748760ee.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-0ba847266de30fc68909.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-309e8f854d010cd0d4bd.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-c5d84128abfe1483557d.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-dfe791db9db8c976a7abb3c9c75727cccd1e792a.yji-aee65fbccc16d5ce97b9.js" rel="preload"/>
# <link as="script" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-03b0bd2e4bc066c55b1e.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ReviewFeedWarEditor" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-eddf561f1306d3813e01fc078aa59de67efd7f02.yji-174a1595a929fc1be52b.js" rel="preload"/>
# <link as="script" data-chunk="components-ReviewFeedWarEditor" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-cc082346baef04de6445.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-2da3d200b3a39dbd90da.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-36d497320a6d633f2a63.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-SEOLinks" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-79f1813c61d8f47d6ed8.chunk.js" rel="preload"/><link data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-82b846e7751e856d88c1.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-775b6c3aa54c4e6f1583.chunk.css" rel="stylesheet"/>
# <link data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css" rel="stylesheet"/>
# <link data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-dad5e49120422e2e9d29.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-456daedc5567db2c2247.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-8343c8d822bd08587711.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-88ca5af3b99587234325.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-ad59b36f17920d25a77f.chunk.css" rel="stylesheet"/><link data-rh="true" href="https://m.yelp.com/biz/cerveseria-catalana-barcelona" media="only screen and (max-width: 640px)" rel="alternate"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link data-rh="true" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona" rel="canonical"/><link data-rh="true" href="android-app://com.yelp.android/yelp-app-indexing/biz/zrxsTCz5lt8q73Hx0GHLDw?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><link data-rh="true" href="ios-app://284910350/yelp//biz/zrxsTCz5lt8q73Hx0GHLDw?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><script data-rh="true">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THHF2RF');</script><script data-rh="true" type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"Yelp","url":"http://www.yelp.com","sameAs":["https://www.facebook.com/yelp","https://twitter.com/yelp","https://www.linkedin.com/company/31517","https://instagram.com/yelp"]}</script><script data-rh="true">!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><title data-rh="true">CERVESERIA CATALANA - 3825 Photos &amp; 1279 Reviews - Spanish - Carrer de Mallorca, 236, Barcelona, Spain - Restaurant Reviews - Phone Number - Yelp</title><meta content="1279 reviews of Cerveseria Catalana &quot;What a gem. We stumbled across it it random, noticing that there was a queue of Barcelonians outside, waiting to get in for their Sunday lunch. DEFINITELY worth a stop to get the real deal of tapas.
#
#
#  There aretwo counters in front with stools for those eating alone (or who don't want to wait for a table). It's large inside, though, with lots of tables, so you might not have to wait too long.
#
#
#  We ate some of the best tapas I've ever had. There was a lot of delicious seafood on offer, too, including some things I don't normally like but that were delicious.
#
#
#  Forest mushrooms grilled in butter and garlic.
# Excellent grilled calamari rings.
# Octopus with potatoes and paprika (never had octopus so tender!).
# Goat cheese and eggplant tart.
# Even the house wine was tasty.
#
#
#  The desserts looked incredible, but we were stuffed beyond capacity.
#
#
#  Prices not bad at all. Tapas ranged from under EUR4 for things like patatas bravas to up in the EUR8 or EUR9 range for things like the octopus. Most were EUR5-ish.
#
#
#  Really good. The restaurant is nice, upscale without being fancy, and likely to be very busy with families on weekends.&quot;" data-rh="true" name="description"/><meta content="zrxsTCz5lt8q73Hx0GHLDw" data-rh="true" name="yelp-biz-id"/><meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" data-rh="true" name="keywords"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="yelpyelp:business" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/bphoto/bHihfh0Dl7HQ-fj3G1ZqsQ/o.jpg" data-rh="true" property="og:image"/><meta content="1236" data-rh="true" property="og:image:height"/><meta content="2000" data-rh="true" property="og:image:width"/><meta content="Cerveseria Catalana - Barcelona, B" data-rh="true" property="og:title"/><meta content="https://www.yelp.com/biz/cerveseria-catalana-barcelona?osq=Restaurant" data-rh="true" property="og:url"/><meta content="" data-rh="true" property="og:description"/><meta content="97534753161" data-rh="true" property="fb:app_id"/><meta content="app-id=284910350, app-argument=yelp:///biz/zrxsTCz5lt8q73Hx0GHLDw?utm_campaign=default&amp;amp;utm_source=www" data-rh="true" name="apple-itunes-app"/><meta content="Yelp" data-rh="true" property="al:ios:app_name"/><meta content="284910350" data-rh="true" property="al:ios:app_store_id"/><meta content="https://www.yelp.com/biz/cerveseria-catalana-barcelona?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple" data-rh="true" property="al:ios:url"/><meta content="Yelp" data-rh="true" name="application-name"/><meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/f5e05563b53a/ico/win8-tile.png" data-rh="true" name="msapplication-TileImage"/><meta content="\#FFFFFF" data-rh="true" name="msapplication-TileColor"/><meta content="https://www.yelp.com" data-rh="true" name="msapplication-starturl"/><meta content="\#FF1A1A" data-rh="true" name="msapplication-navbutton-color"/><meta content="width=1024;height=768" data-rh="true" name="msapplication-window"/><meta content="Go to https://www.yelp.com" data-rh="true" name="msapplication-tooltip"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/>
# <script>document.cookie = "xcj=1|l5Diph2OXJtFxk4SjLAdVBshU8FiJriOFwgkjMvQTH8; Domain=.yelp.com; expires=Mon, 27 Jun 2022 05:22:13 GMT; Max-Age=7776000; Path=/";</script><link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-id="23a17300-5338-479c-8610-94cd59bc4877" data-hypernova-key="yelpfrontend__198__yelpfrontend__GondolaBizDetails__dynamic"><div class="toast-list__09f24__miHvH border-color--default__09f24__NPAKY"></div><span class=""><!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-7">yelp</a> --></span><div class="border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM" data-lcp-target-id="CONSUMER_HEADER"><div class="css-fksa8h padding-t1-5__09f24__VNyRg padding-b1-5__09f24__M_AcV border-color--default__09f24__NPAKY background-color--gray-extra-light__09f24__UbDJH"><div class="a11y-menu-container__09f24__V3Frf border-color--default__09f24__NPAKY"></div></div><header class="consumer-header-container__09f24__ieW2P border--bottom__09f24___mg5X border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM"><div class="consumer-header__09f24__GAvyT border-color--default__09f24__NPAKY"><div class="arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE border-color--default__09f24__NPAKY"><div class="logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class="margin-r4__09f24__mJ91T margin-sm-r0__09f24__WfNsG border-color--default__09f24__NPAKY"><div class="logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB border-color--default__09f24__NPAKY" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__09f24__fS20h css-1sie4w0" href="/" role="link">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="search-suggest-container-outer__09f24__SUL4j border-color--default__09f24__NPAKY"><div class="search-suggest-container-inner__09f24__WsMGR border-color--default__09f24__NPAKY"><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="search-suggest__09f24__Yd8a9"><div class=""><form action="/search" class="find-near-form__09f24__qHR1I" id="header_find_form" method="get" role="search"><div class="undefined arrange__09f24__LDfbs border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="find-near-arrange__09f24__czL3z find-near-arrange--height__09f24__uFYD6 arrange__09f24__LDfbs layout-equal__09f24__odeM0 border-color--default__09f24__NPAKY"><div class="find-near-arrange-unit__09f24__hvHOu arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><label class="label__09f24__2EYit pseudo-input__09f24__nfxxT pseudo-input--find-near__09f24__o_Lff pseudo-input--find__09f24__dWbac pseudo-input__09f24__bK86t" for="search_description"><span class="pseudo-input-text__09f24__PW2ow display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><div class="pseudo-input-icon-container__09f24__WCnQN margin-r1-5__09f24__ot4bd border-color--default__09f24__NPAKY"><span aria-hidden="false" aria-label="Find" class="icon--24-search-v2 pseudo-input-icon__09f24__b1eFr css-147xtl9" role="img"><svg class="icon_svg" height="24" width="24"><path d="M21.853 20.355l-3.444-3.443a9.428 9.428 0 10-16.761-6.171 9.428 9.428 0 0015.34 ...
# The appetizer tapas sampler was amazing and the </span><span class="css-1sb02f4" data-font-weight="bold"><a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=McOMIf_Z501aDMBFe--eoA&amp;rh_ident=razor_clam&amp;rh_type=phrase" role="button">razor clams</a></span><span class="css-qgunke"> are to die for.</span>”<a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=McOMIf_Z501aDMBFe--eoA&amp;rh_ident=razor_clam&amp;rh_type=phrase" role="button"> <!-- -->in 148 reviews</a></p></div></div><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo margin-b1-5__09f24__NHcQi border-color--default__09f24__NPAKY" style="vertical-align:top"><div class="arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class="css-0 border-color--default__09f24__NPAKY"><a class="css-1sie4w0" href="/biz_photos/cerveseria-catalana-barcelona?select=SCkE_10w-f5Putd6PUj3Wg" target="_self"><img alt="" class="css-xlzvdl" draggable="true" height="60" loading="lazy" src="https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/60s.jpg" srcset="https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/ms.jpg 1.67x,https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/120s.jpg 2.00x,https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/90s.jpg 1.50x,https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/168s.jpg 2.80x,https://s3-media0.fl.yelpcdn.com/bphoto/SCkE_10w-f5Putd6PUj3Wg/180s.jpg 3.00x" width="60"/></a></div></div><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><p class="css-2sacua">“<span class="css-qgunke">The patatas bravas are similar to the </span><span class="css-1sb02f4" data-font-weight="bold"><a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=xrexNUtILe29ZL_v3MVWqw&amp;rh_ident=cabreaos&amp;rh_type=phrase" role="button">cabreaos</a></span><span class="css-qgunke"> (minus the eggs) but are more like home fries (cubed potatoes).</span>”<a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=xrexNUtILe29ZL_v3MVWqw&amp;rh_ident=cabreaos&amp;rh_type=phrase" role="button"> <!-- -->in 22 reviews</a></p></div></div><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo margin-b1-5__09f24__NHcQi border-color--default__09f24__NPAKY" style="vertical-align:top"><div class="arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class="css-0 border-color--default__09f24__NPAKY"><a class="css-1sie4w0" href="/biz_photos/cerveseria-catalana-barcelona?select=F6dMIV7eLwflLdaN51O2Og" target="_self"><img alt="" class="css-xlzvdl" draggable="true" height="60" loading="lazy" src="https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/60s.jpg" srcset="https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/ms.jpg 1.67x,https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/120s.jpg 2.00x,https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/90s.jpg 1.50x,https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/168s.jpg 2.80x,https://s3-media0.fl.yelpcdn.com/bphoto/F6dMIV7eLwflLdaN51O2Og/180s.jpg 3.00x" width="60"/></a></div></div><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><p class="css-2sacua">“<span class="css-qgunke">I'm sure our timing was bad for dinner, but overall I had a better experience at </span><span class="css-1sb02f4" data-font-weight="bold"><a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=At--dtCNCezE8WdmoLgWrg&amp;rh_ident=cerveceria_catalana&amp;rh_type=phrase" role="button">Cerveceria Catalana</a></span><span class="css-qgunke">.</span>”<a class="css-1sie4w0" href="https://www.yelp.com/biz/cerveseria-catalana-barcelona?hrid=At--dtCNCezE8WdmoLgWrg&amp;rh_ident=cerveceria_catalana&amp;rh_type=phrase" role="button"> <!-- -->in 30 reviews</a></p></div></ ...
# <script data-hypernova-id="23a17300-5338-479c-8610-94cd59bc4877" data-hypernova-key="yelpfrontend__198__yelpfrontend__GondolaBizDetails__dynamic" type="application/json"><!--{"locale":"en_US","messages":{},"requestCookies":{},"requestHeaders":{},"requestPath":"/biz/cerveseria-catalana-barcelona","requestUrl":"https://www.yelp.com/biz/cerveseria-catalana-barcelona?osq=Restaurant","routeParams":{"businessEncidOrAlias":"cerveseria-catalana-barcelona"},"userId":null,"bizUserId":null,"uniqueRequestId":"95562fe618188f08","site":"www","gaConfig":{"clientID":"08CFB28162F6DB5A","dimensions":{"global":{"full_url":[15,"/biz/cerveseria-catalana-barcelona?osq=Restaurant"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/biz/cerveseria-catalana-barcelona?osq=Restaurant"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.com","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null},"guv":"08CFB28162F6DB5A","legacyProps":{"bizDetailsProps":{"bizDetailsMetaProps":{"businessId":"zrxsTCz5lt8q73Hx0GHLDw","staticUrl":"https://www.yelp.com/biz/cerveseria-catalana-barcelona?osq=Restaurant","selectedReviewId":null,"interfaceLanguageCode":"en","cityPageAlias":"barcelona","appLinks":{"androidUrl":null,"iosUrl":"https://www.yelp.com/biz/cerveseria-catalana-barcelona?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple"},"disallowedRobotsDirectives":null,"googleAppTags":{"androidUrl":"android-app://com.yelp.android/yelp-app-indexing/biz/zrxsTCz5lt8q73Hx0GHLDw?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google","iosUrl":"ios-app://284910350/yelp//biz/zrxsTCz5lt8q73Hx0GHLDw?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google"},"msiteUrl":"https://m.yelp.com/biz/cerveseria-catalana-barcelona"},"bizDetailsPageProps":{"actionBarControllerProps":{"businessId":"zrxsTCz5lt8q73Hx0GHLDw","currentUserDidSave":false,"isLoggedIn":false,"saveTooltipText":null,"shareBusinessModalProps":{"facebookUrl":"http://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fcerveseria-catalana-barcelona%3Futm_campaign%3Dwww_business_share_popup%26utm_medium%3Dsocial%26utm_source%3Dfacebook.com","twitterUrl":"https://twitter.com/share?text=Check+out+Cerveseria+Catalana+on+%40yelp&amp;url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fcerveseria-catalana-barcelona%3Futm_campaign%3Dwww_business_share_popup%26utm_medium%3Dsocial%26utm_source%3Dtwitter.com","shareUrl":"https://www.yelp.com/biz/cerveseria-catalana-barcelona?utm_campaign=www_business_share_popup&amp;utm_medium=copy_link&amp;utm_source=(direct)","contentType":"business","sendToFriendProps":{"loggedIn":false,"submitUrl":"/send_to_friend/business/zrxsTCz5lt8q73Hx0GHLDw","submitCsrfToken":"b'9e8d51d9908440d3f9402b76b5737878c6af480e14f4cbd105d9631446fbd6a1'","findFriendsUrl":"/find_friends/","searchForFriendsUrl":"/send_to_friend/friend_type_ahead_v2","searchForFriendsCsrfToken":"b'c1599b51e1cfd0ba706b488e6a5786a1505b1df3e9eaa3a388d3f6c1a7d272e2'"}},"postingBlockedModalProps":null,"collectionSaveModalProps":{"collectionListUrl":"/collection/user/list_save_collections?item_id=zrxsTCz5lt8q73Hx0GHLDw","createCollectionCsrfToken":"ab779895ab136a5480dc3cd715413cb8275597e91d40cf5c614c785d6336bcb3","createCollectionUrl":"/collection/user/new","itemId":"zrxsTCz5lt8q73Hx0GHLDw","removeItemCsrfToken":"fe1c88832d96bc880c3a91de7c4d630a2be5d722acab3f7b7a4633323fdeaf68","removeItemUrl":"/collection/user/item/remove","saveItemCsrfToken":"64cffba06ba4f57a354742bc8a90f657b6eb5254ad1816da70d6db27560695fb","saveItemUrl":"/collection/user/item/add"}},"adUnitsAboveReviewProps":null,"adUnitsBelowReviewProps":null,"adUnitsSidebarProps":null,"autoOpeningMessagingModalProps":{"iframeUrls":{"mtb_search_ad":"/mtb_composer/business/zrxsTCz5lt8q73Hx0GHLDw/entry_point/mtb_search_ad?source_request_id=3c72b81be528b047","mtb_la ...
# <script crossorigin="anonymous" integrity="sha384-mzQZgPBZXoVR01XpQQ/cDRB2PyBEnY5rOJy13hRfNTc6rj57tdoHqp0lVNW/9ke2" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/f5e755fbcb87/assets/vendor/react-dom/0.0.0-experimental-33c3af284/umd/react-dom.production.min.js"></script>
# <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(t,o){var n=e.css_map[t],a=n.linkTag,i=document.querySelector('style[data-critical-css="'+t+'"]');if(i&&a&&!n.loaded){var r=function(e,t){var o=e.cloneNode();o.rel="stylesheet",o.media="all",o.href=e.href;var n=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return o.setAttribute("onload",n),o.onload=n,o}(a,i);i.insertAdjacentElement("afterend",r),a.parentNode.removeChild(a),e.css_map[t].loaded=!0,function(t){for(var o in e.css_map)if(!e.css_map[o].loaded)return;setTimeout(t,0)}(o)}}function o(o,n){if(!e.css_map||0===Object.keys(e.css_map).length)return void setTimeout(o,0);(n?[n]:Object.keys(e.css_map)).forEach((function(n){e.lowPriorityMode?t(n,o):setTimeout(t,0,n,o)}))}e.criticalCSSReady=function(t){o(t);var n=e.recordDone.bind(window);e.recordDone=function(e,a){n.call(this,e,a),o(t,a.dataset.criticalCss)}}; })()</script>
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.zipkin_id = '5bcbdcc1640f5645';
#         window.yelp.unique_request_id = '95562fe618188f08';
#         window.yelp.guv = '08CFB28162F6DB5A';
#     </script>
# <script crossorigin="anonymous" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js"></script>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "fde284603c8282c7fa387ffdc95c643ba19e2c82", "metaData": {"projectName": "gondola-biz-details", "activeVersion": "1.9.8", "deploymentPreviewId": null, "zipkinTraceID": "5bcbdcc1640f5645"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[4591,6824,5119,5188,5147,1693,1161,9260,4275,2147,1836,8370,8471,1705,9606,6048,968,5903,6254,45,1755,7854,6751]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["ClaimStatusGQL","ClaimReminderGQL","components-UnconfirmedReviewAlert","components-BizPageConfigurableAlertsGQL","OnTheMenuGQL","components-ReviewHighlights","MapBoxV2GQL","BizHoursGQL","components-MoreBusinessInfo","components-ServiceUpdateSummaryGQL","components-BizQuestionsGQL","components-Reviews","components-ReviewFeedWarEditor","components-CollectionCardCarousel","components-RelatedBusinessesCarousel","components-SEOLinks"]}</script>
# <script async="" data-chunk="ClaimStatusGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-5d87a390c86fc7d0bdf9.chunk.js"></script>
# <script async="" data-chunk="ClaimReminderGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-5b5584a8c410c624ac3c.chunk.js"></script>
# <script async="" data-chunk="components-UnconfirmedReviewAlert" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-5f0659d2a4a4f5f55cf0.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-1be7ee6c6c127d99d93e.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-af0fc3a59b1fbdc8c4d1.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-f40cee3c2224261676eb4b46f723e0867d8329bc.yji-581b49d8005d868cf0c0.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-fbb2c05ce72727d2717b02d2c156fdd517bca70a.yji-3018a4f5fe4b3226407a.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8a92b8a262dbf9c3601880010c35a404c0e06edb.yji-ef884a6ded959e9afbc6.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-e55b41b68c176872ae025c8e120f2420c303617a.yji-7b1f1473bce5b8f97dc3.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-34b00f1306f8d2652eed.chunk.js"></script>
# <script async="" data-chunk="components-ReviewHighlights" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewHighlights.yji-1389fc94b8fad2eac6e6.chunk.js"></script>
# <script async="" data-chunk="MapBoxV2GQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-e8661b65e75188e5ee8c.chunk.js"></script>
# <script async="" data-chunk="BizHoursGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-b5b1a5fa1229748760ee.chunk.js"></script>
# <script async="" data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-0ba847266de30fc68909.chunk.js"></script>
# <script async="" data-chunk="components-ServiceUpdateSummaryGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-309e8f854d010cd0d4bd.chunk.js"></script>
# <script async="" data-chunk="components-BizQuestionsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-c5d84128abfe1483557d.chunk.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-dfe791db9db8c976a7abb3c9c75727cccd1e792a.yji-aee65fbccc16d5ce97b9.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-03b0bd2e4bc066c55b1e.chunk.js"></script>
# <script async="" data-chunk="components-ReviewFeedWarEditor" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-eddf561f1306d3813e01fc078aa59de67efd7f02.yji-174a1595a929fc1be52b.js"></script>
# <script async="" data-chunk="components-ReviewFeedWarEditor" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-cc082346baef04de6445.chunk.js"></script>
# <script async="" data-chunk="components-CollectionCardCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-2da3d200b3a39dbd90da.chunk.js"></script>
# <script async="" data-chunk="components-RelatedBusinessesCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-36d497320a6d633f2a63.chunk.js"></script>
# <script async="" data-chunk="components-SEOLinks" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-79f1813c61d8f47d6ed8.chunk.js"></script>
# <script>window.ySitRepParams = {"guv": "08CFB28162F6DB5A", "datacenter": "us-east-1", "unique_request_id": "95562fe618188f08"};</script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_runtime.yji-24ff106708a947789715.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-photo-box-12.0.0.yji-81e4a84f8f4f0ac1524b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-moment-2.29.1.yji-0e2593908c0bf488d81b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-style-utils-5.4.2.yji-afc3661c64e87b21097d.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-lodash-4.17.21.yji-dd097fe2732a8026f3af.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-luxon-1.26.0.yji-746bc59c7d7e8216e930.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-immutable-4.0.0-rc.12.yji-50ef79028a56f4f10674.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-ynra-14.2.6.yji-8c957097ca937e6bb4b5.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_commons.yji-2beaab29c3e6d545685f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-46bb4b98f0a3bb78aca7457251ad9f7f3edaecca.yji-b42fbc91fb452de93e6f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-b15417f6a45cc72a76eb18e6ec64fb6656e0c0a0.yji-40ade416b8ecf1935a69.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-483556bfb011db885de1b785b53a88611d47139e.yji-b09e00ddffd06409dd34.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-1db5f97868d128dbf5860fe972cbb4ea53c95603.yji-f19303381b7d5dede397.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8c6749603f7be3cb402898e06366a23084492b3a.yji-fff4795716fbd4e626ef.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-5c2375b5f919918713f2bdc710f933725e1f41d0.yji-cfb4bfc979580c65bb18.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-81e34133d063ab8aba9b3265276b75d3341c3bca.yji-40d5c67018e43a879909.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-a9ab5a81d7e7d443b49d52e6cb7010b176814d61.yji-186f1f7f0b0766d21812.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cf2daf9e51bb337f183590acc343558b5611a1c0.yji-ff77b422521f24bfa1b7.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-af82791cdd3c3e4b141af5e1ff9170b75be31cd6.yji-b755e48df5e419574b8c.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-5487a827f4f804ea9d4d06e19ba066fc14c4b754.yji-bb965a2ae967921a9bd3.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cbd856d39921184e09721cc9cb3ddcf23f90bb4b.yji-f884ffedf1335a4c2a87.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-0bc009fee474b34b08ecd3c257eb69287c9cae0b.yji-835e5ed6fbfbabd6f12f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-6d99a1f5833cab3bb3bc2e449a12e7eb20b0a491.yji-52018c81778816db1ac5.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8c9fba80c649b6e9e1873c3be238a1dce038f6b8.yji-f09f426655ce242d85a0.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-da3689331a94322025f614e25bb1c62c5344a1ef.yji-d84e740ebf6944114f8b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-075b547d8068ffa7f3654f89300660a59b657565.yji-5647ed9d99a84facf270.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c0faa51540bcf5d815ceff9d6aa8334a4e9054f8.yji-7dd07ae88b8d208cb29c.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-biz-details.yji-6a1098ef5354c6084205.js"></script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#
#             function addCookieManagementScript() {
#                 var tag = document.createElement('script');
#                 tag.async = true;
#                 tag.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';
#                 tag.type = 'text/javascript';
#                 tag.charset = 'UTF-8';
#                 tag.setAttribute('data-domain-script', '5fbcd417-fbc1-4fcc-abad-f622f1bba72d');
#                 tag.setAttribute('data-document-language', 'true');
#
#                 document.head.appendChild(tag);
#             }
#
#             if ('requestIdleCallback' in window) {
#                 requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#             } else {
#                 setTimeout(addCookieManagementScript, 2000);
#             }
#         </script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>

# %% [markdown]
# ## Hotels

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_h = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Hotels&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_h[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:24; Frequency: 0.07495654273124801 requests/s

# %%
# save soup_h
pd.DataFrame([soup_h]).to_csv('hotel_soup.csv')

# %%
# scraping from saved dataframe
names = []
ser = pd.read_csv('hotel_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('.css-1egxyvc .css-1m051bw')
    for tag in result:
        names.append(tag.text)

names
# Out:
# ['Barceló Raval',
#  'Hotel 1898',
#  'W Barcelona',
#  'Hotel Continental Barcelona',
#  'Pulitzer Barcelona',
#  'Le Méridien Barcelona',
#  'Hotel Cotton House',
#  'Hotel Ayre Roselon',
#  'Hotel Majestic',
#  'Renaissance Barcelona Hotel',
#  'Villa Emilia',
#  'Hotel Arts Barcelona',
#  'Mandarin Oriental',
#  'Hotel Jazz',
#  'K+K Hotel Picasso Barcelona',
#  'Hotel Europark',
#  'Grand Hotel Central',
#  'Hotel Barcelona 1882',
#  'Alma Barcelona',
#  'Novotel Barcelona City',
#  'Casa Fuster',
#  'The Barcelona EDITION',
#  'Hotel Barcelona Universal',
#  'Hotel NH Collection Barcelona Gran Hotel Calderón',
#  'H10 Madison',
#  'Claris',
#  'Alexandra Barcelona Hotel',
#  'Hilton Barcelona Hotel',
#  'Hotel Duquesa de Cardona',
#  'Hotel Mercer',
#  'Casa Bonay',
#  'El Palace',
#  'Hotel Praktik',
#  'Hotel U232',
#  'Soho House',
#  'Hotel Catalonia Born',
#  'Hotel Condes de Barcelona',
#  'Hotel Sofia',
#  'Olivia Balmes',
#  'Colonial',
#  'Best Western Premier Hotel Dante',
#  'Arc la Rambla',
#  'Vividora',
#  'Hotel Colón',
#  'H10 Port Vell',
#  'Barcelona Airport Hotel',
#  'Hotel España Ramblas',
#  'Hotel Ohla',
#  'AC Hotel Diagonal L’iIlla',
#  'The Wittmore',
#  'Hilton Diagonal Mar',
#  'The One',
#  'Hotel Catalonia Port',
#  'Hotel Barcelona Catedral',
#  'The Serras',
#  'Sir Victor Hotel',
#  'Room Mate Carla Hotel',
#  'Gallery Hotel',
#  'Iberostar Selection Paseo de Gracia',
#  'Hostal Grau Barcelona',
#  'Renaissance Barcelona Fira Hotel',
#  'Do',
#  'AC Hotel by Marriott Irla',
#  'Axel',
#  'Hotel Sagrada Familia',
#  'Hotel Turin',
#  'Hotel NH Collection Barcelona Pódium',
#  'Eurostars Grand Marina',
#  'Neri',
#  'Millenni',
#  'Hotel Cram',
#  'Sallés Hotel',
#  'Hotel Catalonia Eixample 1864',
#  'Hotel Sixty Two',
#  'Hotel Condal',
#  'Rafaelhoteles Badalona',
#  'Ayre Hotel Rosellón',
#  'Andante Hotel',
#  'Gaudi Hotel Barcelona',
#  'H10 Catalunya Plaza',
#  'Siresa Europea',
#  'Gotico Hotel',
#  'Majestic Residence',
#  'Hotel Catalonia Park Guell',
#  'Nobu Hotel Barcelona',
#  'Royal Ramblas Hotel',
#  'H10 Casa Mimosa',
#  'Praktik Rambla',
#  'Constanza',
#  'Hotel Occidental Atenea Mar',
#  'Olivia Plaza Hotel',
#  'Barcelona Nouvel Hotel',
#  'Ayre Hotel Caspe',
#  'Avenida Palace',
#  'The Mirror Hotel',
#  'Equity Point Centric',
#  'Hotel Medium Prisma',
#  'Hotel Curious',
#  'Hotel Lleó',
#  'Le Palacete',
#  'Hotel Catalonia 505',
#  'Ramblas 108',
#  'Hotel Regencia Colon',
#  'Hotel Del Mar',
#  'Room Mate Pau Hotel',
#  'Alimara',
#  'Hotel Catalonia Diagonal Centro',
#  'Park Hotel',
#  'Hotel Crowne Plaza Fira Center',
#  'AC Hotel by Marriott Barcelona Forum',
#  'Hotel 54 Barceloneta',
#  'Hotel Balmes',
#  'Jorsu Catalana',
#  'Senator Barcelona',
#  'Gaudi Hotel Barcelona',
#  'Gaudí',
#  'Ibis',
#  'The Corner Hotel',
#  'Hotel Nouvel',
#  'Motel One',
#  'Campanile Barcelona Sud-Cornella',
#  'Royal',
#  'Monument Hotel',
#  'Room Mate Anna Hotel',
#  'Hotel Acta Splendid',
#  'NH Constanza',
#  'AC Hotel by Marriott Sants',
#  'hotels barcelona spain',
#  'Soho Barcelona',
#  'Hostalin Barcelona',
#  'Casa Marcelo',
#  'AC Hotel by Marriott Victoria Suites',
#  'Colors',
#  'Hesperia Presidente',
#  'Hotel Miramar',
#  'Hotel Medicis',
#  'Hotel NH Porta Barcelona',
#  'Hotel Ciutadella Barcelona',
#  'St. Christopher’s Inn',
#  'B Hotel',
#  'Catalonia Barcelona Golf',
#  'Mihlton',
#  'Ilunion Almirante',
#  'Hotel Peninsular',
#  'Banys Oriental',
#  'Hotel Capri by Fraser',
#  'Hotel Granados 83',
#  'Hotel Oasis',
#  'Ámister Art Hotel',
#  'Hotel Regina',
#  'St. Christopher’s Inn',
#  'Silken Concordia',
#  'H10 Art Gallery',
#  'Gran Hotel Havana',
#  'AC Hotel by Marriott Som',
#  'Hotel Ciutat Barcelona',
#  'Tryp Apolo Hotel',
#  'Franquesa Malaguti',
#  'Petit Palace Boqueria Garden',
#  'Hotel Casa Camper',
#  'Holiday Inn Express',
#  'Siete Cero DOS Limpiezas Gestionadas',
#  'Hotel Apsis Porta Marina',
#  'Hotel Catalonia',
#  'Banquetes Reunidos',
#  'Fonda Espanya',
#  'Exe Laietana Palace',
#  'Hotel H10',
#  'H10 Metropolitan',
#  'Hotel Ohla Eixample',
#  'Well and Come',
#  'Hotel La Casa del Sol',
#  'Meliá Barcelona',
#  'Hotel Del Compte',
#  'NH Eixample',
#  'HCC Montblanc',
#  'Hotel Bagués',
#  'Hotel Porta Fira',
#  'Santa Marta',
#  'Petit Palace Museum',
#  'Two Hotel',
#  'Ibis Barcelona Centro',
#  'Ficfrei',
#  'H10 Cubik',
#  'Fedasosa',
#  'Hotel Advance',
#  'Praktik Garden',
#  'Hotel Barcelona House',
#  'Hotel NH Barcelona Les Corts',
#  'Four Points by Sheraton Barcelona Diagonal',
#  'Four Points by Sheraton Barcelona Diagonal',
#  'Hotel Apsis Sant Angelo',
#  'ABaC Hotel',
#  'Hotel Nuñez Urgel Comte D’urgell, 232',
#  'Silken Sant Gervasi',
#  'Wilson',
#  'Hostemplo',
#  'Gestion Hotelera Ballester',
#  'Hotel Pelayo',
#  'Sunotel BCN',
#  'Acta Mimic',
#  'Marin Gonzalez Gabriel',
#  'Hotel America',
#  'Hotel Abba Garden',
#  'Hotel Catalonia Portal de l’Angel',
#  'City Park Hotel Sant Just',
#  'Mercer Hoteles',
#  'Hotel Reding',
#  'Acta BCN 40',
#  'OD Barcelona',
#  'Acta BCN 40',
#  'OD Barcelona',
#  'Pullman',
#  'Hotel NH Barcelona Entenza',
#  'Hoteles Solvasa',
#  'Hotel Ibis',
#  'Fairmont Rey Juan Carlos I',
#  'Intown Europe',
#  'Rey Don Jaime I',
#  'Vincci Gala 4',
#  'H10 Montcada',
#  'Almanac',
#  'Hotel Denit',
#  'Hotel Midmost',
#  'Hotel Front Maritim',
#  'Hotel Granvía',
#  'roig cerrudo,ana 000950091r slne',
#  'Sabor Intens',
#  'Aparthotel Silver',
#  'Chic&Basic Velvet',
#  'Chic&Basic Velvet',
#  'Hotel Catalonia Plaza Catalunya',
#  'Omnium',
#  'Ibis Styles',
#  'Patacolls',
#  'Hotel Fira Congress',
#  'ANBA Bed And Breakfast',
#  'Chic & Basic Lemon Boutique',
#  'Tres Torres Atiram',
#  'Abba Rambla']

# %% [markdown]
# ## Pubs

# %%
#  1 webscraping Hotels
# Monitoring of the loop
# start_time = time()
# request = 0

# # Dictionary for storing web content
# soup_p = {}
# for start_num in range(0, 240, 10):

#     # Make a request
#     url = f"https://www.yelp.com/search?find_desc=Pubs&find_loc=Barcelona%2C+Spain&start={start_num}"
#     response = requests.get(url)

#     # Pause the loop
#     sleep(randint(8,15))
#     print(response)
#     page = BeautifulSoup(response.content, 'html.parser')
#     soup_p[start_num] = page


#     # Monitor the requests
#     request += 1
#     elapsed_time = time() - start_time
#     print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
#     clear_output(wait = True)

#     # Throw a warning if request wasn't successful
#     if response.status_code != 200:
#         warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:24; Frequency: 0.07382303659802342 requests/s

# %%
# save soup_p
pd.DataFrame([soup_p]).to_csv('pub_soup.csv')

# %%
# scraping from saved dataframe
names = []
ser = pd.read_csv('pub_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('.css-1egxyvc .css-1m051bw')
    for tag in result:
        names.append(tag.text)
        # names.append(tag.text.split('.')[1].replace('\xa0', ''))

# names
